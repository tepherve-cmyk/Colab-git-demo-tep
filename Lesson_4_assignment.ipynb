# %% [markdown]
# Name: Herve Tepongning Megnifo Student
#
# Number: HT137724
#
# Program: Business Intelligence Analyst
#
# Course: Understanding and Sourcing Data
#
# Assignment 4: Data Processing - Python Development and Pandas

# %%
# Import Libraries

import pandas as pd
import numpy as np
from functools import reduce

# %%
# Task 1: Create a DataFrame using Pandas
# Create a DataFrame with the following data:
# Name: Alice, Bob, Charlie, David
# Age: 25, 30, 35, 28
# City: New York, San Francisco, Los Angeles, Chicago

# Your code here:

data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 28],
    "City": ["New York", "San Francisco", "Los Angeles", "Chicago"]
}

df = pd.DataFrame(data)

# %%
# Task 2: Row and Column Manipulation
# Drop the 'City' column from the DataFrame created in Task 1

# Your code here:

df = df.drop("City", axis=1)

# %%
# Task 3: Handling Null Values
# Create a new DataFrame with some null values and fill them

# Your code here:
data2 = {
    "Car_name": ["Toyota", "Acura", "BMW", "Ford"],
    "Miles": [50025, 75030, 120035, 40028],
    "Color": ["Grey", "Black", "Red", "Blue"]
}

df2 = pd.DataFrame(data)
print(df2.head())
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
# Task 4: GroupBy and Describe
# Using the following DataFrame, group by 'Category' and describe the 'Value' column

df_group = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'B', 'A', 'C'],
    'Value': [10, 20, 15, 25, 30, 35]
})

# Your code here:
grouped_df = df_group.groupby("Category")["Value"].describe()

print(grouped_df)
# Out:
#           count       mean        std   min    25%   50%    75%   max
# Category
# A           3.0  18.333333  10.408330  10.0  12.50  15.0  22.50  30.0
# B           2.0  22.500000   3.535534  20.0  21.25  22.5  23.75  25.0
# C           1.0  35.000000        NaN  35.0  35.00  35.0  35.00  35.0

# %%
# Task 5: Concatenation and Merging
# Concatenate two DataFrames vertically and merge them horizontally

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})
df3 = pd.DataFrame({'C': [9, 10], 'D': [11, 12]})

# Your code here:
concatenated_df = pd.concat([df1, df2], axis=0)
merged_df = pd.concat([concatenated_df, df3], axis=1)

print(merged_df)
# Out:
#    A  B   C   D
# 0  1  3   9  11
# 1  2  4  10  12
# 0  5  7   9  11
# 1  6  8  10  12

# %%
# Task 6: Tuples and Sets

# Create a tuple of fruits and a set of numbers.
# Then, try to add an element to each and observe the difference.

# Your code here:

# Creating a tuple of fruits
fruits = ("apple", "banana", "mango")

# Creating a set of numbers
numbers = {1, 2, 3, 4, 5}

# Using Try to add an element to the tuple

try:
    fruits.append("Orange")
    print("\nFruits:", fruits)
except AttributeError as e:
    print("Tuple:", e)

# Using Try to Add an element to the set number
try:
    numbers.add(6)
    print("\nSet:", numbers)
except AttributeError as e:
    print("\nSet:", e)
# Out:
# Tuple: 'tuple' object has no attribute 'append'
#
# Set: {1, 2, 3, 4, 5, 6}

# %%
"""
Adding an element to a tuple results in an error,
while adding an element to a set does not.
"""
# Out:
# '\n\n'

# %%
# Task 7: Dictionaries
# Create a dictionary of student names and their scores.
# Then, update a student's score and add a new student.

# Your code here:

# Creating Student list

students = {
    "Alice": 85,
    "Bob": 90,
    "Roy": 78,
    "David": 92
}

print(students)

# Update David's score
students["David"] = 98
print(students)

# Add a new student
students["Brown"] = 89
print(students)
# Out:
# {'Alice': 85, 'Bob': 90, 'Roy': 78, 'David': 92}
# {'Alice': 85, 'Bob': 90, 'Roy': 78, 'David': 98}
# {'Alice': 85, 'Bob': 90, 'Roy': 78, 'David': 98, 'Brown': 89}

# %%
# Task 8: Functions and Lambda
# Create a function to calculate the square of a number.
# Then, use a lambda function to do the same.

# Your code here:

# Creating function to calculate the square of a number using a regular function
def square(number):
    return number ** 2

# Creating function to calculate the square of a number using a regular function
square_lambda = lambda x: x ** 2


# testing
print(square(5))
print(square_lambda(5))
# Out:
# 25
# 25

# %%
# Task 9: Iterators and Generators
# Create an iterator for the first 5 even numbers.
# Then, create a generator for the same.

# Your code here:

# Using an iterator
even_numbers = iter([2, 4, 6, 8, 10])

for number in even_numbers:
    print(number)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# Using a generator
def even_numbers():
    for number in range(2, 11, 2):
        yield number

for number in even_numbers():
    print(number)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# Task 10: Map, Reduce, and Filter
# Use map to square all numbers in a list.
# Use reduce to find the product of all numbers in a list.
# Use filter to get only even numbers from a list.

numbers = [1, 2, 3, 4, 5]

# Your code here:

# Using map to square all numbers in a list
squared_numbers = list(map(lambda x: x ** 2, numbers))
print(squared_numbers)

# Using reduce to find the product of all numbers in a list

product = reduce(lambda x, y: x * y, numbers)
print(product)

# Using filter to get only even numbers from a list
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# [1, 4, 9, 16, 25]
# 120
# [2, 4]

# %%
# Task 11: Object-Oriented Programming - Creating a Class
# Create a class called 'Rectangle' with attributes 'length' and 'width'.
# Include methods to calculate area and perimeter.

# Your code here:

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# Example
rectangle = Rectangle(5, 11)
print("Area:", rectangle.area())
print("\nPerimeter:", rectangle.perimeter())
# Out:
# Area: 55
#
# Perimeter: 32

# %%
# Task 12: Pandas Data Analysis
# Using the following DataFrame, perform these tasks:
# 1. Find the average salary by department
# 2. Get the names of employees with salary > 60000
# 3. Add a new column 'Bonus' which is 10% of salary

df_employees = pd.DataFrame({
    'Name': ['John', 'Jane', 'Bob', 'Alice', 'Charlie'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [55000, 65000, 70000, 60000, 58000]
})

# Your code here:

# 1. Find the average salary by department
average_salary = df_employees.groupby("Department")["Salary"].mean()
print(average_salary)
# Out:
# Department
# Finance    60000.0
# HR         61500.0
# IT         62500.0
# Name: Salary, dtype: float64

# %%
# 2. Get the names of employees with salary > 60000
employees_with_high_salary = df_employees[df_employees["Salary"] > 60000]["Name"]
print(employees_with_high_salary)
# Out:
# 1    Jane
# 2     Bob
# Name: Name, dtype: object

# %%
# 3. Add a new column 'Bonus' which is 10% of salary
df_employees["Bonus"] = df_employees["Salary"] * 0.1
print(df_employees)
# Out:
#       Name Department  Salary   Bonus
# 0     John         IT   55000  5500.0
# 1     Jane         HR   65000  6500.0
# 2      Bob         IT   70000  7000.0
# 3    Alice    Finance   60000  6000.0
# 4  Charlie         HR   58000  5800.0
